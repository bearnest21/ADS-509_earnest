# %% [markdown]
# # ADS 509 Module 1: APIs and Web Scraping
#
# This notebook has two parts. In the first part, you will scrape lyrics from AZLyrics.com. In the second part, you'll run code that verifies the completeness of your data pull.
#
# For this assignment you have chosen two musical artists who have at least 20 songs with lyrics on AZLyrics.com. We start with pulling some information and analyzing them.

# %% [markdown]
# ## General Assignment Instructions
#
# These instructions are included in every assignment, to remind you of the coding standards for the class. Feel free to delete this cell after reading it.
#
# One sign of mature code is conforming to a style guide. We recommend the [Google Python Style Guide](https://google.github.io/styleguide/pyguide.html). If you use a different style guide, please include a cell with a link.
#
# Your code should be relatively easy-to-read, sensibly commented, and clean. Writing code is a messy process, so please be sure to edit your final submission. Remove any cells that are not needed or parts of cells that contain unnecessary code. Remove inessential `import` statements and make sure that all such statements are moved into the designated cell.
#
# Make use of non-code cells for written commentary. These cells should be grammatical and clearly written. In some of these cells you will have questions to answer. The questions will be marked by a "Q:" and will have a corresponding "A:" spot for you. *Make sure to answer every question marked with a `Q:` for full credit.*

# %% [markdown]
# # Importing Libraries

# %%
import os
import datetime
import re

# for the lyrics scrape section
import requests
import time
from bs4 import BeautifulSoup
from collections import defaultdict, Counter
import random

# %%
# Use this cell for any import statements you add
import shutil

# %% [markdown]
# ---
#
# # Lyrics Scrape
#
# This section asks you to pull data by scraping www.AZLyrics.com. In the notebooks where you do that work you are asked to store the data in specific ways.

# %%
artists = {'dave':"https://www.azlyrics.com/d/davematthewsband.html",
           'taylor':"https://www.azlyrics.com/t/taylorswift.html"} 
# we'll use this dictionary to hold both the artist name and the link on AZlyrics

# %% [markdown]
# ## A Note on Rate Limiting
#
# The lyrics site, www.azlyrics.com, does not have an explicit maximum on number of requests in any one time, but in our testing it appears that too many requests in too short a time will cause the site to stop returning lyrics pages. (Entertainingly, the page that gets returned seems to only have the song title to [a Tom Jones song](https://www.azlyrics.com/lyrics/tomjones/itsnotunusual.html).)
#
# Whenever you call `requests.get` to retrieve a page, put a `time.sleep(5 + 10*random.random())` on the next line. This will help you not to get blocked. If you _do_ get blocked, which you can identify if the returned pages are not correct, just request a lyrics page through your browser. You'll be asked to perform a CAPTCHA and then your requests should start working again.
#
# ## Part 1: Finding Links to Songs Lyrics
#
# That general artist page has a list of all songs for that artist with links to the individual song pages.
#
# Q: Take a look at the `robots.txt` page on www.azlyrics.com. (You can read more about these pages [here](https://developers.google.com/search/docs/advanced/robots/intro).) Is the scraping we are about to do allowed or disallowed by this page? How do you know?
#
# A: The robot.txt file suggests that two different accesses are disallowed: the lyricsdb and song.

# %%
# Let's set up a dictionary of lists to hold our links
lyrics_pages = defaultdict(list)

for artist, artist_page in artists.items() :
    # request the page and sleep
    r = requests.get(artist_page)
    time.sleep(5 + 10*random.random())

    # now extract the links to lyrics pages from this page
    # store the links `lyrics_pages` where the key is the artist and the
    # value is a list of links. 

    urls = []
    soup = BeautifulSoup(r.text, 'html.parser')

    for link in soup.find_all('a'):
        if ("lyrics/" + artist) in str(link.get('href')):
            urls.append('https://www.azlyrics.com/' + str(link.get('href')))

    lyrics_pages[artist] = urls

# %% [markdown]
# Let's make sure we have enough lyrics pages to scrape.

# %%
for artist, lp in lyrics_pages.items() :
    assert(len(set(lp)) > 20)

# %%
# Let's see how long it's going to take to pull these lyrics 
# if we're waiting `5 + 10*random.random()` seconds 
for artist, links in lyrics_pages.items() : 
    print(f"For {artist} we have {len(links)}.")
    print(f"The full pull will take for this artist will take {round(len(links)*10/3600,2)} hours.")
# Out:
# For dave we have 134.
# The full pull will take for this artist will take 0.37 hours.
# For taylor we have 372.
# The full pull will take for this artist will take 1.03 hours.

# %% [markdown]
# ## Part 2: Pulling Lyrics
#
# Now that we have the links to our lyrics pages, let's go scrape them! Here are the steps for this part.
#
# 1. Create an empty folder in our repo called "lyrics".
# 1. Iterate over the artists in `lyrics_pages`.
# 1. Create a subfolder in lyrics with the artist's name. For instance, if the artist was Cher you'd have `lyrics/cher/` in your repo.
# 1. Iterate over the pages.
# 1. Request the page and extract the lyrics from the returned HTML file using BeautifulSoup.
# 1. Use the function below, `generate_filename_from_url`, to create a filename based on the lyrics page, then write the lyrics to a text file with that name.

# %%
def generate_filename_from_link(link) :
    
    if not link :
        return None
    
    # drop the http or https and the html
    name = link.replace("https","").replace("http","")
    name = link.replace(".html","")

    name = name.replace("/lyrics/","")
    
    # Replace useless chareacters with UNDERSCORE
    name = name.replace("://","").replace(".","_").replace("/","_")
    
    # tack on .txt
    name = name + ".txt"
    
    return(name)

# %%
# Make the lyrics folder here. If you'd like to practice your programming, add functionality 
# that checks to see if the folder exists. If it does, then use shutil.rmtree to remove it and create a new one.

if os.path.isdir("lyrics") : 
    shutil.rmtree("lyrics/")

os.mkdir("lyrics")

# %%
url_stub = "https://www.azlyrics.com" 
start = time.time()

total_pages = 0 

for artist in lyrics_pages :

    # Use this space to carry out the following steps: 
    
    # 1. Build a subfolder for the artist

    if os.path.isdir("lyrics/" + artist):
        shutil.rmtree("lyrics/" + artist)
    
    os.mkdir("lyrics/" + artist)
    # 2. Iterate over the lyrics pages
    # 3. Request the lyrics page. 
        # Don't forget to add a line like `time.sleep(5 + 10*random.random())`
        # to sleep after making the request
    # 4. Extract the title and lyrics from the page.
    # 5. Write out the title, two returns ('\n'), and the lyrics. Use `generate_filename_from_url`
    #    to generate the filename. 

    for lyrics in lyrics_pages[artist]:
        r = requests.get(lyrics)
        time.sleep(5 + 10*random.random())

        soup = BeautifulSoup(r.content, "html.parser")
    
        title = soup.select_one("h1").get_text(strip=True, separator="\n").replace(" lyrics", "").strip('\"')

        lyric = soup.select_one(".ringtone ~ div").get_text(strip=True, separator="\n")

        filename = generate_filename_from_link(lyrics)

        with open(os.path.join("lyrics", artist, filename), 'w') as file:
            file.write(title + '\n\n' + lyric)

        print("Created and closed --> {}".format(filename))
    # Remember to pull at least 20 songs per artist. It may be fun to pull all the songs for the artist
# Out:
# Created and closed --> httpswww_azlyrics_com_davematthewsband_bestofwhatsaround.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_whatwouldyousay.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_satellite.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_rhymereason.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_typicalsituation.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_dancingnancies.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_antsmarching.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_loverlaydown.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_jimithing.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_warehouse.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_payforwhatyouget.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_34.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_somuchtosay.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_twostep.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_crashintome.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_toomuch.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_41.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_saygoodbye.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_driveindriveout.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_letyoudown.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_lieinourgraves.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_cryfreedom.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_trippingbillies.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_proudestmonkey.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_pantalanagapampa.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_rapunzel.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_thelaststop.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_dontdrinkthewater.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_stay.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_halloween.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband_thestone.txt
# Created and closed --> httpswww_azlyrics_com_davematthewsband
txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_closesttoacowboy.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_crazier.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_crossmyheart.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_darkbluetennessee.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_didntthey.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_donthatemeforlovingyou.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_downcametherain.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_dropsofjupiter.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_eyesopen.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_eyesopentaylorsversion.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_fallbackonyou.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_firefly.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_foryou.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_gracie.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_her.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_honeybaby.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_hopelesslydevotedtoyou.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_iheart.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_iknewyouweretroublemusicvideoversion.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_iknewyouweretroubleremix.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_iknowwhatiwant.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_iusedtofly.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_iwantyouback.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_iwishedonaplane.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_idlie.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_ifthiswasamovietaylorsversion.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_inthepouringrain.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_justsouthofknowingwhy.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_lavenderhazeacousticversion.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_letsgobattle.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_liveforthelittlethings.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_longtimecoming.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_lookatyoulikethat.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_lookwhatyoumademedo-video.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_lovestorytaylorsversionelviraremix.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_lovetheyhaventthoughtofyet.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_lovetolose.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_loverfirstdanceremix.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_loverremix.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_luckyyou.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_macavity.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_madeupyou.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_makingupforlostlove.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_mandolin.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_matches.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_meandbritney.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_monologuesonglalala.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_mycure.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_myturntobeme.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_nashville.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_need.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_needyounow.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_neverfade.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_nevermind.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_newromanticsmusicvideoversion.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_onething.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_onewayticket.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_onlytheyoung.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_ourlastnight.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_perfecthaveiloved.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_permanentmarker.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_pointofview.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_revenge.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_riptide.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_ronan.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_run.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_safeandsound.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_safesoundtaylorsversion.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_samegirl.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_september.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_smokeyblacknights.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_spinningaround.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_stupidboy.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_sugar.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_sweetescape.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_sweetteaandgodsgraces.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_sweeterthanfiction.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_tellme.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_tendollarsandasixpack.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_tennessee.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_thatslife.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_thatswhen.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_thediaryofme.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_theresyourtrouble.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_thirteenblockscantcallitlove.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_thishereguitar.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_thisisreallyhappening.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_thislovetaylorsversion.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_thugstory.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_tilbradpittcomesalong.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_todaywasafairytale.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_undermyhead.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_vivalavida.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_waitforme.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_wewerehappy.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_welcomedistraction.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_whatdoyousay.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_whattowear.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_whoivealwaysbeen.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_wildestdreamstaylorsversion.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_writingsongsaboutyou.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_youdo.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_youranything.txt
# Created and closed --> httpswww_azlyrics_com_taylorswift_yourface.txt

# %%
print(f"Total run time was {round((time.time() - start)/3600,2)} hours.")
# Out:
# Total run time was 1.46 hours.

# %% [markdown]
# ---
#
# # Evaluation
#
# This assignment asks you to pull data by scraping www.AZLyrics.com.  After you have finished the above sections , run all the cells in this notebook. Print this to PDF and submit it, per the instructions.

# %%
# Simple word extractor from Peter Norvig: https://norvig.com/spell-correct.html
def words(text): 
    return re.findall(r'\w+', text.lower())

# %% [markdown]
# ## Checking Lyrics
#
# The output from your lyrics scrape should be stored in files located in this path from the directory:
# `/lyrics/[Artist Name]/[filename from URL]`. This code summarizes the information at a high level to help the instructor evaluate your work.

# %%
artist_folders = os.listdir("lyrics/")
artist_folders = [f for f in artist_folders if os.path.isdir("lyrics/" + f)]

for artist in artist_folders : 
    artist_files = os.listdir("lyrics/" + artist)
    artist_files = [f for f in artist_files if 'txt' in f or 'csv' in f or 'tsv' in f]

    print(f"For {artist} we have {len(artist_files)} files.")

    artist_words = []

    for f_name in artist_files : 
        with open("lyrics/" + artist + "/" + f_name) as infile : 
            artist_words.extend(words(infile.read()))

            
    print(f"For {artist} we have roughly {len(artist_words)} words, {len(set(artist_words))} are unique.")
# Out:
# For dave we have 134 files.
# For dave we have roughly 34778 words, 2319 are unique.
# For taylor we have 372 files.
# For taylor we have roughly 132849 words, 4603 are unique.
